# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import preprocessing
from sklearn.model_selection import train_test_split, StratifiedKFold, cross_val_score
from sklearn.metrics import roc_auc_score, accuracy_score, confusion_matrix, classification_report
# featuretools for automated feature engineering
import featuretools as ft
import featuretools.variable_types as vtypes

# %%
arpu_train =  pd.read_csv('data/arpu_train.csv')
arpu_test =  pd.read_csv('data/arpu_test.csv')

arpu_train_info = pd.read_csv('data/arpu_info_train.csv').replace({365243: np.nan})
arpu_test_info = pd.read_csv('data/arpu_info_test.csv').replace({365243: np.nan})

arpu_miseri_train = pd.read_csv('data/arpu_miseri_train.csv').replace({365243: np.nan})
arpu_miseri_test = pd.read_csv('data/arpu_miseri_test.csv').replace({365243: np.nan})

# %%
es1 = ft.EntitySet(id = 'es1')
es2 = ft.EntitySet(id = 'es2')
es1 = es1.entity_from_dataframe(entity_id = 'arpu_miseri_train', dataframe = arpu_miseri_train, 
                              make_index = True, index = 'miseri_index_train')
es2 = es2.entity_from_dataframe(entity_id = 'arpu_miseri_test', dataframe = arpu_miseri_test, 
                              make_index = True, index = 'miseri_index_test')

# %%
# List the primitives in a dataframe
primitives = ft.list_primitives()
pd.options.display.max_colwidth = 100

# primitives[primitives['type'] == 'aggregation']
primitives[primitives['type'] == 'transform']
# Out:
#                                name       type  dask_compatible  \
# 22                              and  transform             True
# 23            modulo_numeric_scalar  transform             True
# 24                        longitude  transform            False
# 25                         cum_mean  transform            False
# 26                 multiply_boolean  transform             True
# 27               add_numeric_scalar  transform             True
# 28            greater_than_equal_to  transform             True
# 29                             week  transform             True
# 30                             hour  transform             True
# 31                             isin  transform             True
# 32                     greater_than  transform             True
# 33                              day  transform             True
# 34                               or  transform             True
# 35                           second  transform             True
# 36               less_than_equal_to  transform             True
# 37                              not  transform             True
# 38                divide_by_feature  transform             True
# 39                 subtract_numeric  transform             True
# 40                             year  transform             True
# 41                       time_since  transform             True
# 42          subtract_numeric_scalar  transform             True
# 43                   modulo_numeric  transform             True
# 44          multiply_numeric_scalar  transform             True
# 45                              age  transform             True
# 46                          weekday  transform             True
# 47                          cum_min  transform            False
# 48                 not_equal_scalar  transform             True
# 49                        not_equal  transform             True
# 50                        less_than  transform             True
# 51                            month  transform             True
# 52                        cum_count  transform            False
# 53                 multiply_numeric  transform             True
# 54                     equal_scalar  transform             True
# 55     greater_than_equal_to_scalar  transform             True
# 56                         latitude  transform            False
# 57                           minute  transform             True
# 58                          cum_sum  transform            False
# 59                           negate  transform             True
# 60                            equal  transform             True
# 61              greater_than_scalar  transform             True
# 62                      add_numeric  transform             True
# 63              time_since_previous  transform            False
# 64                   num_characters  transform             True
# 65        less_than_equal_to_scalar  transform             True
# 66                        haversine  transform            False
# 67                         absolute  transform             True
# 68                   divide_numeric  transform             True
# 69                 less_than_scalar  transform             True
# 70                             diff  transform            False
# 71                          is_null  transform             True
# 72                modulo_by_feature  transform             True
# 73            divide_numeric_scalar  transform             True
# 74                        num_words  transform             True
# 75                          cum_max  transform            False
# 76  scalar_subtract_numeric_feature  transform             True
# 77                       percentile  transform            False
# 78                       is_weekend  transform             True
#
#     koalas_compatible  \
# 22               True
# 23               True
# 24              False
# 25              False
# 26              False
# 27               True
# 28               True
# 29               True
# 30               True
# 31               True
# 32              False
# 33               True
# 34               True
# 35               True
# 36               True
# 37               True
# 38               True
# 39              False
# 40               True
# 41              False
# 42               True
# 43               True
# 44               True
# 45              False
# 46               True
# 47              False
# 48               True
# 49              False
# 50               True
# 51               True
# 52              False
# 53               True
# 54               True
# 55               True
# 56              False
# 57               True
# 58              False
# 59               True
# 60               True
# 61               True
# 62               True
# 63              False
# 64               True
# 65               True
# 66              False
# 67               True
# 68               True
# 69               True
# 70              False
# 71               True
# 72               True
# 73               True
# 74               True
# 75              False
# 76               True
# 77              False
# 78               True
#
#                                                                     description
# 22                                       Element-wise logical AND of two lists.
# 23                   Return the modulo of each element in the list by a scalar.
# 24                  Returns the second tuple value in a list of LatLong tuples.
# 25                                              Calculates the cumulative mean.
# 26                  Element-wise multiplication of two lists of boolean values.
# 27                                      Add a scalar to each value in the list.
# 28  Determines if values in one list are greater than or equal to another list.
# 29                             Determines the week of the year from a datetime.
# 30                                     Determines the hour value of a datetime.
# 31                    Determines whether a value is present in a provided list.
# 32              Determines if values in one list are greater than another list.
# 33                             Determines the day of the month from a datetime.
# 34                                        Element-wise logical OR of two lists.
# 35                                  Determines the seconds value of a datetime.
# 36     Determines if values in one list are less than or equal to another list.
# 37                                                     Negates a boolean value.
# 38                                   Divide a scalar by each value in the list.
# 39                                       Element-wise subtraction of two lists.
# 40                                     Determines the year value of a datetime.
# 41                 Calculates time from a value to a specified cutoff datetime.
# 42                             Subtract a scalar from each element in the list.
# 43                                            Element-wise modulo of two lists.
# 44                               Multiply each element in the list by a scalar.
# 45               Calculates the age in years as a floating point number given a
# 46                              Determines the day of the week from a datetime.
# 47                                           Calculates the cumulative minimum.
# 48              Determines if values in a list are not equal to a given scalar.
# 49              Determines if values in one list are not equal to another list.
# 50                 Determines if values in one list are less than another list.
# 51                                    Determines the month value of a datetime.
# 52                                             Calculates the cumulative count.
# 53                                    Element-wise multiplication of two lists.
# 54                  Determines if values in a list are equal to a given scalar.
# 55            Determines if values are greater than or equal to a given scalar.
# 56                   Returns the first tuple value in a list of LatLong tuples.
# 57                                  Determines the minutes value of a datetime.
# 58                                               Calculates the cumulative sum.
# 59                                                     Negates a numeric value.
# 60                  Determines if values in one list are equal to another list.
# 61                        Determines if values are greater than a given scalar.
# 62                                          Element-wise addition of two lists.
# 63                         Compute the time since the previous entry in a list.
# 64                             Calculates the number of characters in a string.
# 65               Determines if values are less than or equal to a given scalar.
# 66            Calculates the approximate haversine distance between two LatLong
# 67                                     Computes the absolute value of a number.
# 68                                          Element-wise division of two lists.
# 69                           Determines if values are less than a given scalar.
# 70                   Compute the difference between the value in a list and the
# 71                                               Determines if a value is null.
# 72                   Return the modulo of a scalar by each element in the list.
# 73                                 Divide each element in the list by a scalar.
# 74           Determines the number of words in a string by counting the spaces.
# 75                                           Calculates the cumulative maximum.
# 76                         Subtract each value in the list from a given scalar.
# 77                     Determines the percentile rank for each value in a list.
# 78                                     Determines if a date falls on a weekend.

# %%
# Default primitives from featuretools
agg_primitives =  []
trans_primitives = ['cum_mean','is_null']

# DFS with specified primitives
feature_matrix1, feature_names1 = ft.dfs(entityset=es1, target_entity='arpu_miseri_train',
                                       agg_primitives = agg_primitives,
                                       trans_primitives = trans_primitives,
                                       n_jobs = 8, verbose = 10, features_only = False,
                                       max_depth = 1000, chunk_size = 1000)

# DFS with specified primitives
feature_matrix2, feature_names2 = ft.dfs(entityset=es2, target_entity='arpu_miseri_test',
                                       agg_primitives = agg_primitives,
                                       trans_primitives = trans_primitives,
                                       n_jobs = 8, verbose = 10, features_only = False,
                                       max_depth = 1000, chunk_size = 1000)
# Out:
# Built 27 features
# EntitySet scattered to 8 workers in 8 seconds
# Elapsed: 00:02 | Progress: 100%|███████████████████████████████████████████████████████████████████████████████████████
# Built 27 features
# EntitySet scattered to 8 workers in 7 seconds
# Elapsed: 00:03 | Progress: 100%|███████████████████████████████████████████████████████████████████████████████████████

# %%
feature_matrix1.reset_index(inplace = True)
feature_matrix1.to_csv('data/arpu_feature_train.csv', index = False)
feature_matrix2.reset_index(inplace = True)
feature_matrix2.to_csv('data/arpu_feature_test.csv', index = False)

# %%
feature_train = pd.read_csv('data/arpu_feature_train.csv')
feature_test = pd.read_csv('data/arpu_feature_test.csv')

# %%
feature_train= feature_train.drop(['IS_NULL(msisdn)','IS_NULL(miseri_index_train)'],axis = 1)
feature_train= feature_train.drop(['CUM_MEAN(COL_20)','CUM_MEAN(COL_21)','CUM_MEAN(COL_22)','CUM_MEAN(COL_27a)','CUM_MEAN(COL_27b)','CUM_MEAN(COL_27c)','CUM_MEAN(COL_27d)'],axis = 1)
feature_test= feature_test.drop(['CUM_MEAN(COL_20)','CUM_MEAN(COL_21)','CUM_MEAN(COL_22)','CUM_MEAN(COL_27a)','CUM_MEAN(COL_27b)','CUM_MEAN(COL_27c)','CUM_MEAN(COL_27d)'],axis = 1)
feature_test = feature_test.drop(['IS_NULL(msisdn)','IS_NULL(miseri_index_test)'],axis = 1)
feature_train= feature_train.drop(['IS_NULL(COL_21)','IS_NULL(COL_22)','IS_NULL(COL_27a)','IS_NULL(COL_27b)','IS_NULL(COL_27c)','IS_NULL(COL_27d)'],axis = 1)
feature_test = feature_test.drop(['IS_NULL(COL_21)','IS_NULL(COL_22)','IS_NULL(COL_27a)','IS_NULL(COL_27b)','IS_NULL(COL_27c)','IS_NULL(COL_27d)'],axis = 1)
# feature_train= feature_train.drop(['PERCENTILE(COL_21)'],axis = 1)
# feature_test= feature_test.drop(['PERCENTILE(COL_21)'],axis = 1)

# feature_train= feature_train.drop(['CUM_MEAN(COL_19)'],axis = 1)
# feature_test= feature_test.drop(['CUM_MEAN(COL_19)'],axis = 1)

# %%
for col in feature_train.columns:
    # Check if the column is of object type
    if feature_train[col].dtypes == 'object':
        # Impute with the most frequent value
        feature_train = feature_train.fillna(0)

for col in feature_test.columns:
    # Check if the column is of object type
    if feature_test[col].dtypes == 'object':
        # Impute with the most frequent value
        feature_test = feature_test.fillna(0)
        
feature_train.to_csv('data/feature_train.csv', index = False)
feature_test.to_csv('data/feature_test.csv', index = False)

# %%
def rank_simple(vector):
    return sorted(range(len(vector)), key=vector.__getitem__)

def rankdata(a):
    n = len(a)
    ivec=rank_simple(a)
    svec=[a[rank] for rank in ivec]
    sumranks = 0
    dupcount = 0
    newarray = [0]*n
    for i in range(n):
        sumranks += i
        dupcount += 1
        if i==n-1 or svec[i] != svec[i+1]:
            averank = sumranks / float(dupcount) + 1
            for j in range(i-dupcount+1,i+1):
                newarray[ivec[j]] = averank
            sumranks = 0
            dupcount = 0
    return newarray

# %%
def get_age_bin(a):
    age_bin = []
    n = len(a)
    for i in a:
        if i <1950 or i >2000:
            age_bin.append(0)
        else:
            age_bin.append(1)
    return age_bin

# %%
feature_train['age_bin'] = get_age_bin(arpu_train_info['COL_14'])
feature_test['age_bin'] = get_age_bin(arpu_test_info['COL_14'])

# %%
arpu_train_info['COL_14'].fillna(arpu_train_info['COL_14'].mean(), inplace=True)
arpu_test_info['COL_14'].fillna(arpu_test_info['COL_14'].mean(), inplace=True)

# %%
feature_train['rank_col_19'] = rankdata(feature_train['COL_19'])
feature_train['rank_col_20']  = rankdata(feature_train['COL_20'])
feature_train['rank_col_21']  = rankdata(feature_train['COL_21'])
feature_train['rank_col_22']  = rankdata(feature_train['COL_22'])
feature_train['rank_col_27a']  = rankdata(feature_train['COL_27a'])
feature_train['rank_col_27b']  = rankdata(feature_train['COL_27b'])
feature_train['rank_col_27c']  = rankdata(feature_train['COL_27c'])
feature_train['rank_col_27d']  = rankdata(feature_train['COL_27d'])

feature_test['rank_col_19'] = rankdata(feature_test['COL_19'])
feature_test['rank_col_20']  = rankdata(feature_test['COL_20'])
feature_test['rank_col_21']  = rankdata(feature_test['COL_21'])
feature_test['rank_col_22']  = rankdata(feature_test['COL_22'])
feature_test['rank_col_27a']  = rankdata(feature_test['COL_27a'])
feature_test['rank_col_27b']  = rankdata(feature_test['COL_27b'])
feature_test['rank_col_27c']  = rankdata(feature_test['COL_27c'])
feature_test['rank_col_27d']  = rankdata(feature_test['COL_27d'])

# %%
feature_train= feature_train.drop(['COL_19', 'COL_20', 'COL_21', 'COL_22', 'COL_27a', 'COL_27b', 'COL_27c', 'COL_27d'],axis = 1)
feature_test= feature_test.drop(['COL_19', 'COL_20', 'COL_21', 'COL_22', 'COL_27a', 'COL_27b', 'COL_27c', 'COL_27d'],axis = 1)
feature_train= feature_train.drop(['miseri_index_train'],axis = 1)
feature_test= feature_test.drop(['miseri_index_test'],axis = 1)

# %%
feature_train.to_csv('data/feature_train.csv', index = False)
feature_test.to_csv('data/feature_test.csv', index = False)

# %%
feature_train
# Out:
#                      msisdn  CUM_MEAN(COL_19)  IS_NULL(COL_19)  \
# 0      00010016bb53e8e3c82e      90909.093750            False
# 1      0001007187b4881379a9      59560.096680            False
# 2      000100829f9d67fff3cc     112726.921224            False
# 3      000100a5e09da7ad6649     115903.003418            False
# 4      000100d7f3d9e70f62b0     133105.488672            False
# ...                     ...               ...              ...
# 57716  0001e0e2c7aed96ff2fc     102311.797262            False
# 57717  0001f99f298dd21ce8c5     102310.539594            False
# 57718  0001fa0c3d21c0d758ec     102308.967581            False
# 57719  0001fc8336def40dff4b     102310.721938            False
# 57720  0001fd58309b6e1168cb     102310.341733            False
#
#        IS_NULL(COL_20)  age_bin  rank_col_19  rank_col_20  rank_col_21  \
# 0                 True        1      32316.0       7588.5      27418.5
# 1                False        1      16446.0      25726.0      27418.5
# 2                False        1      51214.0      46250.0      27418.5
# 3                False        1      40729.0      54246.0      27418.5
# 4                False        1      50012.0      51209.0      27418.5
# ...                ...      ...          ...          ...          ...
# 57716            False        1      32769.0      51099.0      27418.5
# 57717            False        1      16880.0      40945.0      27418.5
# 57718            False        1      11003.0      19320.5      27418.5
# 57719            False        1      50137.0      55911.0      27418.5
# 57720            False        1      29955.0      17930.0      27418.5
#
#        rank_col_22  rank_col_27a  rank_col_27b  rank_col_27c  rank_col_27d
# 0           9790.0        2961.5        2961.5        5674.5        3034.0
# 1          33887.0       43355.0       43511.0       33294.0       43998.0
# 2          55837.0       46486.0       46665.0       48439.0       47242.0
# 3          23040.0       48753.0       48772.0       44247.0       48438.0
# 4          54171.0       46589.0       46758.0       50858.0       45080.0
# ...            ...           ...           ...           ...           ...
# 57716      43973.0       27347.0       27293.0       28337.0       31016.0
# 57717      21953.5       55881.0       55948.0       48627.0       56150.0
# 57718       9790.0       31428.0       35769.0       15571.0       38978.0
# 57719      48049.0       37835.0       37793.0       38143.0       38927.0
# 57720       9790.0       52997.0       53017.0       40704.0       52665.0
#
# [57721 rows x 13 columns]

# %% [markdown]
# # relationship

# %%
call_train = pd.read_csv('data/call_train.csv').replace({365243: np.nan})
call_test = pd.read_csv('data/call_test.csv').replace({365243: np.nan})
call_train = call_train.drop(['call_time','Unnamed','COL_1','PARTNER_MSISDN','call_train_index'], axis = 1)
call_test = call_test.drop(['call_time','Unnamed','COL_1','PARTNER_MSISDN','call_test_index'], axis = 1)

# %%
call_train

# %%
# Entity set with id applications
es3 = ft.EntitySet(id = 'es3')
es4 = ft.EntitySet(id = 'es4')

arpu_train_info_types = {}
arpu_test_info_types = {}
arpu_train_info_types['COL_13'] = vtypes.Categorical
arpu_train_info_types['COL_14'] = vtypes.Ordinal
arpu_train_info_types['COL_15'] = vtypes.Categorical
arpu_train_info_types['COL_16'] = vtypes.Categorical
arpu_train_info_types['COL_17'] = vtypes.Categorical
arpu_train_info_types['COL_18'] = vtypes.Categorical

arpu_test_info_types['COL_13'] = vtypes.Categorical
arpu_test_info_types['COL_14'] = vtypes.Ordinal
arpu_test_info_types['COL_15'] = vtypes.Categorical
arpu_test_info_types['COL_16'] = vtypes.Categorical
arpu_test_info_types['COL_17'] = vtypes.Categorical
arpu_test_info_types['COL_18'] = vtypes.Categorical

es3 = es3.entity_from_dataframe(entity_id = 'arpu_train_info', dataframe = arpu_train_info, index = 'msisdn',
                              variable_types = arpu_train_info_types)
es3 = es3.entity_from_dataframe(entity_id = 'call_train', dataframe = call_train, 
                              make_index = True, index = 'call_train_index')

es4 = es4.entity_from_dataframe(entity_id = 'arpu_test_info', dataframe = arpu_test_info, index = 'msisdn',
                              variable_types = arpu_test_info_types)
es4 = es4.entity_from_dataframe(entity_id = 'call_test', dataframe = call_test, 
                              make_index = True, index = 'call_test_index')

r_arpu_3 = ft.Relationship(es3['arpu_train_info']['msisdn'], es3['call_train']['msisdn'])
r_arpu_4 = ft.Relationship(es4['arpu_test_info']['msisdn'], es4['call_test']['msisdn'])

es3 = es3.add_relationships([r_arpu_3])
es4 = es4.add_relationships([r_arpu_4])

# %%
 primitives[primitives['type'] == 'aggregation']

# %%
# Default primitives from featuretools
agg_primitives =  ['mean','sum','trend']
trans_primitives = []

# DFS with specified primitives
feature_matrix3, feature_names3 = ft.dfs(entityset=es3, target_entity='arpu_train_info',
                                       agg_primitives = agg_primitives,
                                       trans_primitives = trans_primitives,
                                       n_jobs = 1, verbose = 10, features_only = False,
                                       max_depth = 1000, chunk_size = 1000)

# DFS with specified primitives
feature_matrix4, feature_names4 = ft.dfs(entityset=es4, target_entity='arpu_test_info',
                                       agg_primitives = agg_primitives,
                                       trans_primitives = trans_primitives,
                                       n_jobs = 1, verbose = 10, features_only = False,
                                       max_depth = 1000, chunk_size = 1000)

# %%
feature_matrix3.reset_index(inplace = True)
feature_matrix4.reset_index(inplace = True)

# %%
feature_matrix3

# %%
feature_matrix4
